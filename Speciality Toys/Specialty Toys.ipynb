# %% [markdown]
# # <center><u>Specialty Toys Assignment</u></center>
#
# ## <font color="red">Case Problem</font>
#
#
# Specialty Toys, Inc., sells a variety of new and innovative children’s toys. Management
# learned that the preholiday season is the best time to introduce a new toy, because many
# families use this time to look for new ideas for December holiday gifts. When Specialty discovers a new toy with good market potential, it chooses an October market entry date.
# In order to get toys in its stores by October, Specialty places one-time orders with its manufacturers in June or July of each year. Demand for children’s toys can be highly volatile.
# If a new toy catches on, a sense of shortage in the marketplace often increases the demand
# to high levels and large profits can be realized. However, new toys can also flop, leaving Specialty stuck with high levels of inventory that must be sold at reduced prices. The most important question the company faces is deciding how many units of a new toy should be
# purchased to meet anticipated sales demand. If too few are purchased, sales will be lost; if too many are purchased, profits will be reduced because of low prices realized in clearance sales.
#
# For the coming season, Specialty plans to introduce a new product called Weather
# Teddy. This variation of a talking teddy bear is made by a company in Taiwan. When a child presses Teddy’s hand, the bear begins to talk. A built-in barometer selects one of five responses that predict the weather conditions. The responses range from “It looks to be a very
# nice day! Have fun” to “I think it may rain today. Don’t forget your umbrella.” Tests with
# the product show that, even though it is not a perfect weather predictor, its predictions are surprisingly good. Several of Specialty’s managers claimed Teddy gave predictions of the
# weather that were as good as many local television weather forecasters.
#
# As with other products, Specialty faces the decision of how many Weather Teddy units
# to order for the coming holiday season. Members of the management team suggested order quantities of 15,000, 18,000, 24,000, or 28,000 units. The wide range of order quantities
# suggested indicates considerable disagreement concerning the market potential.
# The product management team asks you for an analysis of the stock-out probabilities for
# various order quantities, an estimate of the profit potential, and to help make an order quantity recommendation. Specialty expects to sell Weather Teddy for 24 dollars based on a cost of 16 dollars per unit.
#
# If inventory remains after the holiday season, Specialty will sell all surplus inventory for $5 per unit. After reviewing the sales history of similar products, Specialty’s seniorsales forecaster predicted an expected demand of 20,000 units with a .95 probability
# that demand would be between 10,000 units and 30,000 units.
#
# Prepare a managerial report that addresses the following issues and recommends an order quantity for the Weather Teddy product.
#
# 1. Use the sales forecaster’s prediction to describe a normal probability distribution that can be used to approximate the demand distribution. Sketch the distribution and show its mean and standard deviation.
# 2. Compute the probability of a stock-out for the order quantities suggested by members of the management team.
# 3. Compute the projected profit for the order quantities suggested by the management team under three scenarios: worst case in which sales 10,000 units, most likely case in which sales 20,000 units, and best case in which sales 30,000 units.

# %% [markdown]
# # <center><u>Assignment Solution</u></center>
#
# ## Information given
#
# Let X be the demand for the toy.  We are given below
#
# #### P (10000 < X < 30000) = 0.95
#
# Assuming the demand to be normally distributed, we can deduce that there is only **5%** chance that the demand will either below **10,000** or more than **30,000** units.
#
# We are also aware that a Gaussian distribution is symmetric in nature so there is only **2.5%** chance that the demand will soar pass 30,000. In other words we have a **97.5%** probability that the orders will be contained within this limit.
#
# To get the Z score for .975 probability, we can look at the Z table or calculate the Z score with R qnorm function with below settings

# %%
#Mean= 0 , Sd =1
Z=qnorm(0.975,0,1)
Z
# Out:
# [1] 1.959964

# %% [markdown]
# #### So, Z= 1.96 (approx.)
#
# Also, it is given that the average demand for the season to be 20,000
#
# **μ = 20,000**
#
# Based on Z score equation, we obtain the Standard Deviation (σ)
#
# **Z = (x – μ) / σ**
#
# 1.96 = (30,000 -20,000) / σ
#
# σ = (30000-20000)/1.96 =10000/1.96
#
# **σ = 5102.04(approx.)**

# %% [markdown]
# ## Estimates
#
# To draw estimates, we will create a user function **gen_normal** in R which will produce normal distribution curve predicated on   **± 3.5 σ** boundaries.
#
# Since (± 3.5 σ) encapsulates **99.97%** of the density distribution of a Gaussian estimate, we are going to assume these to be the endpoints and the remaining **.03%** can be absorbed while rounding of the estimates.
#
# Below is how our generator function looks like:

# %% [markdown]
# #### The function takes 4 argument
# 1.	Mean- mean of the PD curve.
# 2.	SD-  standard deviation of the PD curve
# 3.	LB- lower bound ( in case of a range a supplied)
# 4.	UB- Upper Bound  (in case of a range or cumulative probability is required for both left and right tail)
#
# The default value of lb=0 and ub=1 implies that no lower or upper bound has been specified respectively.
#
#
#
# ---

# %% [markdown]
# # <Center><u>Managerial Report</u><Center>
#
# ## Demand Distribution
#
# The distribution curve can be approximated with a normal distribution
#
# **µ = 20000 and σ = 5102**.

# %%
gen_normal (20000, 5102)
# Out:
# Plot with title “Demand”

# %% [markdown]
# #### Similarly a 95% confidence can be shown with lb=10,000 and ub=30,000

# %%
gen_normal (20000, 5102,lb=10000,ub=30000)
# Out:
# Plot with title “Demand”

# %% [markdown]
# ## Stock-Out Probability
#
# Probability of stock out with an order of K units is **P(X > K) = 1-P (Z= (K-20000)/5102))**,
# where Z is distributed as standard normal.
#
#
#
# | Order (K) | Z=(K-20000)/5102  |  P(X > K)     |
# |-----------|-------------------|---------------|
# |  15000    |     -0.98001      |  0.836458876  |
# |  18000    |     -0.392        |  0.652472052  |
# |  24000    |     0.784006      |  0.216518215  |
# |  28000    |     1.568013      |  0.058439102  |
#
#
# This can also be calculated with pnorm distribution function in R and we can visualize each order
# Probability distribution with function gen_normal as below

# %% [markdown]
# ### Order(K=15000)

# %%
gen_normal(20000, 5102,ub=15000)
# Out:
# Plot with title “Demand”

# %% [markdown]
# ### Order(K=18000)

# %%
gen_normal (20000, 5102,ub=18000)
# Out:
# Plot with title “Demand”

# %% [markdown]
# ### Order(k=24000)

# %%
gen_normal (20000, 5102,ub=24000)
# Out:
# Plot with title “Demand”

# %% [markdown]
# ### Order(k=28000)

# %%
gen_normal (20000, 5102,ub=28000)
# Out:
# Plot with title “Demand”

# %% [markdown]
# ## Projected Profit/Loss
#
# The net amount is calculated for all three projected scenarios(10000,20000,30000) against the recommendation of manangement team.
#
#
# | Order     | Scenario 10000             |  Scenario 20000          |  Scenario 30000  |
# |-----------|----------------------------|--------------------------|------------------|
# |  15000    |8x10000 - 11x5000  = 25000  | 8x15000 = 120000         | 8x15000 = 120000 |
# |  18000    |8x10000 - 11x8000  = -8000  | 8x18000 = 144000         | 8x18000 = 144000 |
# |  24000    |8x10000 - 11x14000 = -74000 | 8x20000 -11x4000 = 116000| 8x24000 = 192000 |
# |  28000    |8x10000 - 11x18000 = -118000| 8x2000 - 11x8000 = 72000 | 8x28000 = 224000 |

# %% [markdown]
# ## Suggestion
#
# It is important to point out that Specialty Toys Inc. will be making an estimated profit of **8** dollars per Weather Teddy during the festive period, but post that, a loss of **11** dollars per piece for the surplus inventory.
#
# Therefore, if we assume of selling ‘X’ toys in profit and ‘Y’ in loss, the break-even point comes as per below equation if everything else goes as planned
#
# **8x -11y = 0 => x= (11/8) *y **
#
# **x =1.375y**
#
# or
#
# **y= x/1.375**
#
# Since this toy is a new offering, taking a conservative approach and a measurable risk appetite is the way forward. A similar order quantity table is given below
#
#
# | Risk Appetite |  Minimum Expected Sale (X)   |Loss Bearing Capacity | Total Order Quantity |
# |---------------|------------------------------|----------------------|----------------------|
# |  2.5%         |qnorm(.025,20000,5102) =10000 |10000/1.375 = 7273    | 10000 + 7273 = 17273 |
# |  5.0%         |qnorm(.050,20000,5102) =11608 |11608/1.375 = 8442    | 11608 + 8442 = 20050 |
# |  7.5%         |qnorm(.075,20000,5102) =12656 |12656/1.375 = 9204    | 12656 + 9204 = 21860 |
# |  10.0%        |qnorm(.10,20000,5102) =13462  |13462/1.375 = 9790    | 13462 + 9790 = 23252 |
#
# In conclusion, the suggestion is to stay below the 10% limit in any case owing to massive volatility around demand for children’s toy.

# %%
qnorm(.025,20000,5102)
# Out:
# [1] 10000.26

# %%
qnorm(.050,20000,5102)
# Out:
# [1] 11607.96

# %%
qnorm(.075,20000,5102)
# Out:
# [1] 12655.51

# %%
qnorm(.10,20000,5102)
# Out:
# [1] 13461.52
